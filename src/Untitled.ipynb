# %%
from rl import pi4
# Out:
# /home/jacques/repos/jmnel/neuralsort/data/iex_tops.sqlite3
# imported
# Episode: 1
# Episode: 1, avg. train reward: -239.52471923828125, loss: 0.29681396484375
# Buy: 250, sell: 249
# Flat: 498, long: 501
# Net: 0.0
#
# Episode: 2
# Episode: 2, avg. train reward: -228.6661376953125, loss: -0.22310638427734375
# Buy: 240, sell: 240
# Flat: 519, long: 480
# Net: 0.0
#
# Episode: 3
# Episode: 3, avg. train reward: -225.23843383789062, loss: 0.0876312255859375
# Buy: 236, sell: 235
# Flat: 524, long: 475
# Net: 0.0
#
# Episode: 4
# Episode: 4, avg. train reward: -246.56739807128906, loss: -0.061126708984375
# Buy: 258, sell: 258
# Flat: 515, long: 484
# Net: 0.0
#
# Episode: 5
# Episode: 5, avg. train reward: -223.69850158691406, loss: 0.2846221923828125
# Buy: 235, sell: 234
# Flat: 527, long: 472
# Net: 0.0
#
# Episode: 6
# Episode: 6, avg. train reward: -237.0637664794922, loss: -0.211181640625
# Buy: 249, sell: 249
# Flat: 542, long: 457
# Net: 0.0
#
# Episode: 7
# ...
